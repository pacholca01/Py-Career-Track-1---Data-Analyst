# %% [markdown]
# #### 1 Matplotlib
#
# Data visualization is a key skill for aspiring data scientists. Matplotlib makes it easy to create meaningful and insightful plots. In this chapter, you’ll learn how to build various types of plots, and customize them to be more visually appealing and interpretable.
#
# ###### Line plot (1)
# With matplotlib, you can create a bunch of different plots in Python. The most basic plot is the line plot. A general recipe is given here.
#
# import matplotlib.pyplot as plt
# plt.plot(x,y)
# plt.show()
# In the video, you already saw how much the world population has grown over the past years. Will it continue to do so? The world bank has estimates of the world population for the years 1950 up to 2100. The years are loaded in your workspace as a list called year, and the corresponding populations as a list called pop.
#
# This course touches on a lot of concepts you may have forgotten, so if you ever need a quick refresher, download the Python for data science Cheat Sheet and keep it handy!

# %%
year = [1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035, 2036, 2037, 2038, 2039, 2040, 2041, 2042, 2043, 2044, 2045, 2046, 2047, 2048, 2049, 2050, 2051, 2052, 2053, 2054, 2055, 2056, 2057, 2058, 2059, 2060, 2061, 2062, 2063, 2064, 2065, 2066, 2067, 2068, 2069, 2070, 2071, 2072, 2073, 2074, 2075, 2076, 2077, 2078, 2079, 2080, 2081, 2082, 2083, 2084, 2085, 2086, 2087, 2088, 2089, 2090, 2091, 2092, 2093, 2094, 2095, 2096, 2097, 2098, 2099, 2100]
pop = [2.53, 2.57, 2.62, 2.67, 2.71, 2.76, 2.81, 2.86, 2.92, 2.97, 3.03, 3.08, 3.14, 3.2, 3.26, 3.33, 3.4, 3.47, 3.54, 3.62, 3.69, 3.77, 3.84, 3.92, 4.0, 4.07, 4.15, 4.22, 4.3, 4.37, 4.45, 4.53, 4.61, 4.69, 4.78, 4.86, 4.95, 5.05, 5.14, 5.23, 5.32, 5.41, 5.49, 5.58, 5.66, 5.74, 5.82, 5.9, 5.98, 6.05, 6.13, 6.2, 6.28, 6.36, 6.44, 6.51, 6.59, 6.67, 6.75, 6.83, 6.92, 7.0, 7.08, 7.16, 7.24, 7.32, 7.4, 7.48, 7.56, 7.64, 7.72, 7.79, 7.87, 7.94, 8.01, 8.08, 8.15, 8.22, 8.29, 8.36, 8.42, 8.49, 8.56, 8.62, 8.68, 8.74, 8.8, 8.86, 8.92, 8.98, 9.04, 9.09, 9.15, 9.2, 9.26, 9.31, 9.36, 9.41, 9.46, 9.5, 9.55, 9.6, 9.64, 9.68, 9.73, 9.77, 9.81, 9.85, 9.88, 9.92, 9.96, 9.99, 10.03, 10.06, 10.09, 10.13, 10.16, 10.19, 10.22, 10.25, 10.28, 10.31, 10.33, 10.36, 10.38, 10.41, 10.43, 10.46, 10.48, 10.5, 10.52, 10.55, 10.57, 10.59, 10.61, 10.63, 10.65, 10.66, 10.68, 10.7, 10.72, 10.73, 10.75, 10.77, 10.78, 10.79, 10.81, 10.82, 10.83, 10.84, 10.85]

# Print the last item from year and pop
print(year[-1],pop[-1])

from matplotlib import pyplot as plt

x = year
y = pop
plt.plot(x,y)
plt.show()
# Out:
# 2100 10.85

# %% [markdown]
# ##### Line plot (3)
# Now that you've built your first line plot, let's start working on the data that professor Hans Rosling used to build his beautiful bubble chart. It was collected in 2007. Two lists are available for you:
#
# life_exp which contains the life expectancy for each country and
# gdp_cap, which contains the GDP per capita (i.e. per person) for each country expressed in US Dollars.
# GDP stands for Gross Domestic Product. It basically represents the size of the economy of a country. Divide this by the population and you get the GDP per capita.
#
# matplotlib.pyplot is already imported as plt, so you can get started straight away.

# %%
life_exp = [43.828, 76.423, 72.301, 42.731, 75.32, 81.235, 79.829, 75.635, 64.062, 79.441, 56.728, 65.554, 74.852, 50.728, 72.39, 73.005, 52.295, 49.58, 59.723, 50.43, 80.653, 44.74100000000001, 50.651, 78.553, 72.961, 72.889, 65.152, 46.462, 55.322, 78.782, 48.328, 75.748, 78.273, 76.486, 78.332, 54.791, 72.235, 74.994, 71.33800000000001, 71.878, 51.57899999999999, 58.04, 52.947, 79.313, 80.657, 56.735, 59.448, 79.406, 60.022, 79.483, 70.259, 56.007, 46.388000000000005, 60.916, 70.19800000000001, 82.208, 73.33800000000001, 81.757, 64.69800000000001, 70.65, 70.964, 59.545, 78.885, 80.745, 80.546, 72.567, 82.603, 72.535, 54.11, 67.297, 78.623, 77.58800000000001, 71.993, 42.592, 45.678, 73.952, 59.443000000000005, 48.303, 74.241, 54.467, 64.164, 72.801, 76.195, 66.803, 74.543, 71.164, 42.082, 62.069, 52.906000000000006, 63.785, 79.762, 80.204, 72.899, 56.867, 46.859, 80.196, 75.64, 65.483, 75.53699999999999, 71.752, 71.421, 71.688, 75.563, 78.098, 78.74600000000001, 76.442, 72.476, 46.242, 65.528, 72.777, 63.062, 74.002, 42.568000000000005, 79.972, 74.663, 77.926, 48.159, 49.339, 80.941, 72.396, 58.556, 39.613, 80.884, 81.70100000000001, 74.143, 78.4, 52.517, 70.616, 58.42, 69.819, 73.923, 71.777, 51.542, 79.425, 78.242, 76.384, 73.747, 74.249, 73.422, 62.698, 42.38399999999999, 43.487]
gdp_cap = [974.5803384, 5937.029525999999, 6223.367465, 4797.231267, 12779.37964, 34435.367439999995, 36126.4927, 29796.04834, 1391.253792, 33692.60508, 1441.284873, 3822.137084, 7446.298803, 12569.85177, 9065.800825, 10680.79282, 1217.032994, 430.0706916, 1713.778686, 2042.09524, 36319.23501, 706.016537, 1704.063724, 13171.63885, 4959.114854, 7006.580419, 986.1478792, 277.5518587, 3632.557798, 9645.06142, 1544.750112, 14619.222719999998, 8948.102923, 22833.30851, 35278.41874, 2082.4815670000003, 6025.374752000001, 6873.262326000001, 5581.180998, 5728.353514, 12154.08975, 641.3695236000001, 690.8055759, 33207.0844, 30470.0167, 13206.48452, 752.7497265, 32170.37442, 1327.60891, 27538.41188, 5186.050003, 942.6542111, 579.2317429999999, 1201.637154, 3548.3308460000003, 39724.97867, 18008.94444, 36180.78919, 2452.210407, 3540.651564, 11605.71449, 4471.061906, 40675.99635, 25523.2771, 28569.7197, 7320.880262000001, 31656.06806, 4519.461171, 1463.249282, 1593.06548, 23348.139730000003, 47306.98978, 10461.05868, 1569.331442, 414.5073415, 12057.49928, 1044.770126, 759.3499101, 12451.6558, 1042.581557, 1803.151496, 10956.99112, 11977.57496, 3095.7722710000003, 9253.896111, 3820.17523, 823.6856205, 944.0, 4811.060429, 1091.359778, 36797.93332, 25185.00911, 2749.320965, 619.6768923999999, 2013.977305, 49357.19017, 22316.19287, 2605.94758, 9809.185636, 4172.838464, 7408.905561, 3190.481016, 15389.924680000002, 20509.64777, 19328.70901, 7670.122558, 10808.47561, 863.0884639000001, 1598.435089, 21654.83194, 1712.472136, 9786.534714, 862.5407561000001, 47143.17964, 18678.31435, 25768.25759, 926.1410683, 9269.657808, 28821.0637, 3970.095407, 2602.394995, 4513.480643, 33859.74835, 37506.41907, 4184.548089, 28718.27684, 1107.482182, 7458.396326999999, 882.9699437999999, 18008.50924, 7092.923025, 8458.276384, 1056.380121, 33203.26128, 42951.65309, 10611.46299, 11415.80569, 2441.576404, 3025.349798, 2280.769906, 1271.211593, 469.70929810000007]

x = gdp_cap
y = life_exp
# Make a line plot, gdp_cap on the x-axis, life_exp on the y-axis
plt.plot(x,y)
plt.show()

# %% [markdown]
# ##### Scatter Plot (1)
# When you have a time scale along the horizontal axis, the line plot is your friend. But in many other cases, when you're trying to assess if there's a correlation between two variables, for example, the scatter plot is the better choice. Below is an example of how to build a scatter plot.
#
# import matplotlib.pyplot as plt
# plt.scatter(x,y)
# plt.show()
# Let's continue with the gdp_cap versus life_exp plot, the GDP and life expectancy data for different countries in 2007. Maybe a scatter plot will be a better alternative?
#
# Again, the matplotlib.pyplot package is available as plt.

# %%
# Change the line plot below to a scatter plot
plt.scatter(x,y)
plt.show()

# %%
plt.scatter(x,y)

# Put the x-axis on a logarithmic scale
plt.xscale('log')
plt.show()

# %% [markdown]
# ##### Scatter plot (2)
# In the previous exercise, you saw that the higher GDP usually corresponds to a higher life expectancy. In other words, there is a positive correlation.
#
# Do you think there's a relationship between population and life expectancy of a country? The list life_exp from the previous exercise is already available. In addition, now also pop is available, listing the corresponding populations for the countries in 2007. The populations are in millions of people.

# %%
pop = [31.889923, 3.600523, 33.333216, 12.420476, 40.301927, 20.434176, 8.199783, 0.708573, 150.448339, 10.392226, 8.078314, 9.119152, 4.552198, 1.639131, 190.010647, 7.322858, 14.326203, 8.390505, 14.131858, 17.696293, 33.390141, 4.369038, 10.238807, 16.284741, 1318.683096, 44.22755, 0.71096, 64.606759, 3.80061, 4.133884, 18.013409, 4.493312, 11.416987, 10.228744, 5.46812, 0.496374, 9.319622, 13.75568, 80.264543, 6.939688, 0.551201, 4.906585, 76.511887, 5.23846, 61.083916, 1.454867, 1.688359, 82.400996, 22.873338, 10.70629, 12.572928, 9.947814, 1.472041, 8.502814, 7.483763, 6.980412, 9.956108, 0.301931, 1110.396331, 223.547, 69.45357, 27.499638, 4.109086, 6.426679, 58.147733, 2.780132, 127.467972, 6.053193, 35.610177, 23.301725, 49.04479, 2.505559, 3.921278, 2.012649, 3.193942, 6.036914, 19.167654, 13.327079, 24.821286, 12.031795, 3.270065, 1.250882, 108.700891, 2.874127, 0.684736, 33.757175, 19.951656, 47.76198, 2.05508, 28.90179, 16.570613, 4.115771, 5.675356, 12.894865, 135.031164, 4.627926, 3.204897, 169.270617, 3.242173, 6.667147, 28.674757, 91.077287, 38.518241, 10.642836, 3.942491, 0.798094, 22.276056, 8.860588, 0.199579, 27.601038, 12.267493, 10.150265, 6.144562, 4.553009, 5.447502, 2.009245, 9.118773, 43.997828, 40.448191, 20.378239, 42.292929, 1.133066, 9.031088, 7.554661, 19.314747, 23.174294, 38.13964, 65.068149, 5.701579, 1.056608, 10.276158, 71.158647, 29.170398, 60.776238, 301.139947, 3.447496, 26.084662, 85.262356, 4.018332, 22.211743, 11.746035, 12.311143]
life_exp = [43.828, 76.423, 72.301, 42.731, 75.32, 81.235, 79.829, 75.635, 64.062, 79.441, 56.728, 65.554, 74.852, 50.728, 72.39, 73.005, 52.295, 49.58, 59.723, 50.43, 80.653, 44.74100000000001, 50.651, 78.553, 72.961, 72.889, 65.152, 46.462, 55.322, 78.782, 48.328, 75.748, 78.273, 76.486, 78.332, 54.791, 72.235, 74.994, 71.33800000000001, 71.878, 51.57899999999999, 58.04, 52.947, 79.313, 80.657, 56.735, 59.448, 79.406, 60.022, 79.483, 70.259, 56.007, 46.388000000000005, 60.916, 70.19800000000001, 82.208, 73.33800000000001, 81.757, 64.69800000000001, 70.65, 70.964, 59.545, 78.885, 80.745, 80.546, 72.567, 82.603, 72.535, 54.11, 67.297, 78.623, 77.58800000000001, 71.993, 42.592, 45.678, 73.952, 59.443000000000005, 48.303, 74.241, 54.467, 64.164, 72.801, 76.195, 66.803, 74.543, 71.164, 42.082, 62.069, 52.906000000000006, 63.785, 79.762, 80.204, 72.899, 56.867, 46.859, 80.196, 75.64, 65.483, 75.53699999999999, 71.752, 71.421, 71.688, 75.563, 78.098, 78.74600000000001, 76.442, 72.476, 46.242, 65.528, 72.777, 63.062, 74.002, 42.568000000000005, 79.972, 74.663, 77.926, 48.159, 49.339, 80.941, 72.396, 58.556, 39.613, 80.884, 81.70100000000001, 74.143, 78.4, 52.517, 70.616, 58.42, 69.819, 73.923, 71.777, 51.542, 79.425, 78.242, 76.384, 73.747, 74.249, 73.422, 62.698, 42.38399999999999, 43.487]

x = pop
y = life_exp 
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ##### Build a histogram (1)
# life_exp, the list containing data on the life expectancy for different countries in 2007, is available in your Python shell.
#
# To see how life expectancy in different countries is distributed, let's create a histogram of life_exp.
#
# matplotlib.pyplot is already available as plt.

# %%
plt.hist(y)
plt.show()

# %% [markdown]
# ##### Build a histogram (2): bins
# In the previous exercise, you didn't specify the number of bins. By default, Python sets the number of bins to 10 in that case. The number of bins is pretty important. Too few bins will oversimplify reality and won't show you the details. Too many bins will overcomplicate reality and won't show the bigger picture.
#
# To control the number of bins to divide your data in, you can set the bins argument.
#
# That's exactly what you'll do in this exercise. You'll be making two plots here. The code in the script already includes plt.show() and plt.clf() calls; plt.show() displays a plot; plt.clf() cleans it up again so you can start afresh.
#
# As before, life_exp is available and matplotlib.pyplot is imported as plt.

# %%
plt.hist(y, bins=5)
plt.show()

# Show and clean up plot
plt.show()
plt.clf()

# Build histogram with 20 bins
plt.hist(y,bins=20)

# Show and clean up again
plt.show()
plt.clf()

# %% [markdown]
# ##### Build a histogram (3): compare
# In the video, you saw population pyramids for the present day and for the future. Because we were using a histogram, it was very easy to make a comparison.
#
# Let's do a similar comparison. life_exp contains life expectancy data for different countries in 2007. You also have access to a second list now, life_exp1950, containing similar data for 1950. Can you make a histogram for both datasets?
#
# You'll again be making two plots. The plt.show() and plt.clf() commands to render everything nicely are already included. Also matplotlib.pyplot is imported for you, as plt.

# %%
# Histogram of life_exp, 15 bins
plt.hist(y,bins=15)

# Show and clear plot
plt.show()
plt.clf()

life_exp1950 = [28.8, 55.23, 43.08, 30.02, 62.48, 69.12, 66.8, 50.94, 37.48, 68.0, 38.22, 40.41, 53.82, 47.62, 50.92, 59.6, 31.98, 39.03, 39.42, 38.52, 68.75, 35.46, 38.09, 54.74, 44.0, 50.64, 40.72, 39.14, 42.11, 57.21, 40.48, 61.21, 59.42, 66.87, 70.78, 34.81, 45.93, 48.36, 41.89, 45.26, 34.48, 35.93, 34.08, 66.55, 67.41, 37.0, 30.0, 67.5, 43.15, 65.86, 42.02, 33.61, 32.5, 37.58, 41.91, 60.96, 64.03, 72.49, 37.37, 37.47, 44.87, 45.32, 66.91, 65.39, 65.94, 58.53, 63.03, 43.16, 42.27, 50.06, 47.45, 55.56, 55.93, 42.14, 38.48, 42.72, 36.68, 36.26, 48.46, 33.68, 40.54, 50.99, 50.79, 42.24, 59.16, 42.87, 31.29, 36.32, 41.72, 36.16, 72.13, 69.39, 42.31, 37.44, 36.32, 72.67, 37.58, 43.44, 55.19, 62.65, 43.9, 47.75, 61.31, 59.82, 64.28, 52.72, 61.05, 40.0, 46.47, 39.88, 37.28, 58.0, 30.33, 60.4, 64.36, 65.57, 32.98, 45.01, 64.94, 57.59, 38.64, 41.41, 71.86, 69.62, 45.88, 58.5, 41.22, 50.85, 38.6, 59.1, 44.6, 43.58, 39.98, 69.18, 68.44, 66.07, 55.09, 40.41, 43.16, 32.55, 42.04, 48.45]

# Histogram of life_exp1950, 15 bins
plt.hist(life_exp1950,bins=15)

# Show and clear plot again
plt.show()
plt.clf()

# %% [markdown]
# ##### Labels
# It's time to customize your own plot. This is the fun part, you will see your plot come to life!
#
# You're going to work on the scatter plot with world development data: GDP per capita on the x-axis (logarithmic scale), life expectancy on the y-axis. The code for this plot is available in the script.
#
# As a first step, let's add axis labels and a title to the plot. You can do this with the xlabel(), ylabel() and title() functions, available in matplotlib.pyplot. This sub-package is already imported as plt

# %%
gdp_cap = [974.5803384, 5937.029525999999, 6223.367465, 4797.231267, 12779.37964, 34435.367439999995, 36126.4927, 29796.04834, 1391.253792, 33692.60508, 1441.284873, 3822.137084, 7446.298803, 12569.85177, 9065.800825, 10680.79282, 1217.032994, 430.0706916, 1713.778686, 2042.09524, 36319.23501, 706.016537, 1704.063724, 13171.63885, 4959.114854, 7006.580419, 986.1478792, 277.5518587, 3632.557798, 9645.06142, 1544.750112, 14619.222719999998, 8948.102923, 22833.30851, 35278.41874, 2082.4815670000003, 6025.374752000001, 6873.262326000001, 5581.180998, 5728.353514, 12154.08975, 641.3695236000001, 690.8055759, 33207.0844, 30470.0167, 13206.48452, 752.7497265, 32170.37442, 1327.60891, 27538.41188, 5186.050003, 942.6542111, 579.2317429999999, 1201.637154, 3548.3308460000003, 39724.97867, 18008.94444, 36180.78919, 2452.210407, 3540.651564, 11605.71449, 4471.061906, 40675.99635, 25523.2771, 28569.7197, 7320.880262000001, 31656.06806, 4519.461171, 1463.249282, 1593.06548, 23348.139730000003, 47306.98978, 10461.05868, 1569.331442, 414.5073415, 12057.49928, 1044.770126, 759.3499101, 12451.6558, 1042.581557, 1803.151496, 10956.99112, 11977.57496, 3095.7722710000003, 9253.896111, 3820.17523, 823.6856205, 944.0, 4811.060429, 1091.359778, 36797.93332, 25185.00911, 2749.320965, 619.6768923999999, 2013.977305, 49357.19017, 22316.19287, 2605.94758, 9809.185636, 4172.838464, 7408.905561, 3190.481016, 15389.924680000002, 20509.64777, 19328.70901, 7670.122558, 10808.47561, 863.0884639000001, 1598.435089, 21654.83194, 1712.472136, 9786.534714, 862.5407561000001, 47143.17964, 18678.31435, 25768.25759, 926.1410683, 9269.657808, 28821.0637, 3970.095407, 2602.394995, 4513.480643, 33859.74835, 37506.41907, 4184.548089, 28718.27684, 1107.482182, 7458.396326999999, 882.9699437999999, 18008.50924, 7092.923025, 8458.276384, 1056.380121, 33203.26128, 42951.65309, 10611.46299, 11415.80569, 2441.576404, 3025.349798, 2280.769906, 1271.211593, 469.70929810000007]
life_exp = [43.828, 76.423, 72.301, 42.731, 75.32, 81.235, 79.829, 75.635, 64.062, 79.441, 56.728, 65.554, 74.852, 50.728, 72.39, 73.005, 52.295, 49.58, 59.723, 50.43, 80.653, 44.74100000000001, 50.651, 78.553, 72.961, 72.889, 65.152, 46.462, 55.322, 78.782, 48.328, 75.748, 78.273, 76.486, 78.332, 54.791, 72.235, 74.994, 71.33800000000001, 71.878, 51.57899999999999, 58.04, 52.947, 79.313, 80.657, 56.735, 59.448, 79.406, 60.022, 79.483, 70.259, 56.007, 46.388000000000005, 60.916, 70.19800000000001, 82.208, 73.33800000000001, 81.757, 64.69800000000001, 70.65, 70.964, 59.545, 78.885, 80.745, 80.546, 72.567, 82.603, 72.535, 54.11, 67.297, 78.623, 77.58800000000001, 71.993, 42.592, 45.678, 73.952, 59.443000000000005, 48.303, 74.241, 54.467, 64.164, 72.801, 76.195, 66.803, 74.543, 71.164, 42.082, 62.069, 52.906000000000006, 63.785, 79.762, 80.204, 72.899, 56.867, 46.859, 80.196, 75.64, 65.483, 75.53699999999999, 71.752, 71.421, 71.688, 75.563, 78.098, 78.74600000000001, 76.442, 72.476, 46.242, 65.528, 72.777, 63.062, 74.002, 42.568000000000005, 79.972, 74.663, 77.926, 48.159, 49.339, 80.941, 72.396, 58.556, 39.613, 80.884, 81.70100000000001, 74.143, 78.4, 52.517, 70.616, 58.42, 69.819, 73.923, 71.777, 51.542, 79.425, 78.242, 76.384, 73.747, 74.249, 73.422, 62.698, 42.38399999999999, 43.487]

x = gdp_cap
y = life_exp

# Basic scatter plot, log scale
plt.scatter(x, y)
plt.show()

plt.scatter(x, y)
plt.xscale('log') 

# Strings
xlab = 'GDP per Capita [in USD]'
ylab = 'Life Expectancy [in years]'
title = 'World Development in 2007'

# Add axis labels
plt.xlabel(xlab)
plt.ylabel(ylab)


# Add title
plt.title(title)

# After customizing, display the plot
plt.show()

# %% [markdown]
# ##### Ticks
# The customizations you've coded up to now are available in the script, in a more concise form.
#
# In the video, Hugo has demonstrated how you could control the y-ticks by specifying two arguments:
#
# plt.yticks([0,1,2], ["one","two","three"])
# In this example, the ticks corresponding to the numbers 0, 1 and 2 will be replaced by one, two and three, respectively.
#
# Let's do a similar thing for the x-axis of your world development chart, with the xticks() function. The tick values 1000, 10000 and 100000 should be replaced by 1k, 10k and 100k. To this end, two lists have already been created for you: tick_val and tick_lab.

# %%
print(pd.DataFrame(x))
# Out:
#                 0
# 0      974.580338
# 1     5937.029526
# 2     6223.367465
# 3     4797.231267
# 4    12779.379640
# ..            ...
# 137   2441.576404
# 138   3025.349798
# 139   2280.769906
# 140   1271.211593
# 141    469.709298
#
# [142 rows x 1 columns]

# %%
plt.scatter(x, y)
plt.xscale('log')

# Strings
xlab = 'GDP per Capita [in USD]'
ylab = 'Life Expectancy [in years]'
title = 'World Development in 2007'

# Add labels
plt.xlabel(xlab)
plt.ylabel(ylab)
plt.title(title)

tick_value = [1000, 10000, 100000]
tick_lab = ['1k', '10k', '100k']

plt.xticks(tick_value, tick_lab, rotation=20)
plt.show()

# %% [markdown]
# ##### Sizes
# Right now, the scatter plot is just a cloud of blue dots, indistinguishable from each other. Let's change this. Wouldn't it be nice if the size of the dots corresponds to the population?
#
# To accomplish this, there is a list pop loaded in your workspace. It contains population numbers for each country expressed in millions. You can see that this list is added to the scatter method, as the argument s, for size.

# %%
import numpy as np

plt.clf() 
plt.rcParams["figure.figsize"]=15,10

# Store pop as numpy array
np_pop = np.array(pop)

# Double pop numpy array
size = np_pop * 3

plt.scatter(x, y, s = size)
# plt.xscale('log')

log_tick_value = [1000, 10000, 50000]
log_tick_lab = ['1k', '10k', '50k']

# Add labels
plt.xlabel(xlab)
plt.ylabel(ylab)
plt.title(title)
# plt.xticks(tick_value, tick_lab, rotation=20)
plt.xticks(log_tick_value, log_tick_lab, rotation=20)
plt.show()
plt.clf()

plt.scatter(x, y, s = size)
plt.xscale('log')

# Add labels
plt.xlabel(xlab)
plt.ylabel(ylab)
plt.title(title)
plt.xticks(tick_value, tick_lab, rotation=20)
# plt.xticks(log_tick_value, log_tick_lab, rotation=20)


plt.show()

# %%
import pandas as pd

fn = 'life_expectancy_years.csv'

gapminder_life_exp = pd.read_csv(fn)
print(gapminder_life_exp.head())

# gmle_2007 = gapminder_life_exp['2007']
# print(gmle_2007.head())

gmle_2007 = gapminder_life_exp[['country','2007']]
print()
print(gmle_2007.head())

# gmle_2007['color'] = gmle_2007.country
# Out:
#                 country  1799  1800  1801  1802  1803  1804  1805  1806  1807  \
# 0           Afghanistan  28.2  28.2  28.2  28.2  28.2  28.2  28.1  28.1  28.1
# 1                Angola  27.0  27.0  27.0  27.0  27.0  27.0  27.0  27.0  27.0
# 2               Albania  35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4
# 3               Andorra   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  United Arab Emirates  30.7  30.7  30.7  30.7  30.7  30.7  30.7  30.7  30.7
#
#    ...  2090  2091  2092  2093  2094  2095  2096  2097  2098  2099
# 0  ...  75.5  75.7  75.8  76.0  76.1  76.2  76.4  76.5  76.6  76.8
# 1  ...  78.8  79.0  79.1  79.2  79.3  79.5  79.6  79.7  79.9  80.0
# 2  ...  87.4  87.5  87.6  87.7  87.8  87.9  88.0  88.2  88.3  88.4
# 3  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  ...  82.4  82.5  82.6  82.7  82.8  82.9  83.0  83.1  83.2  83.3
#
# [5 rows x 302 columns]
#
#                 country  2007
# 0           Afghanistan  59.2
# 1                Angola  58.8
# 2               Albania  77.6
# 3               Andorra  81.8
# 4  United Arab Emirates  70.4

# %%
# !pip3 install pycountry
# !pip3 install pprintpp
# !pip3 install pycountry-convert

# %%
import pycountry_convert as pc
def convert(row):
    cn_code = pc.country_name_to_country_alpha2(row.country, cn_name_format = 'default')
    
    conti_code = pc.country_alpha2_to_continent_code(cn_code)
    return conti_code

# %%
gmle_2007.continent = gmle_2007.apply(convert, axis=1)
gmle_2007
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [208], in <cell line: 1>()
# ----> 1 gmle_2007.continent = gmle_2007.apply(convert, axis=1)
#       2 gmle_2007
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/frame.py:8839, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8828 from pandas.core.apply import frame_apply
#    8830 op = frame_apply(
#    8831     self,
#    8832     func=func,
#    (...)
#    8837     kwargs=kwargs,
#    8838 )
# -> 8839 return op.apply().__finalize__(self, method="apply")
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/apply.py:727, in FrameApply.apply(self)
#     724 elif self.raw:
#     725     return self.apply_raw()
# --> 727 return self.apply_standard()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/apply.py:851, in FrameApply.apply_standard(self)
#     850 def apply_standard(self):
# --> 851     results, res_index = self.apply_series_generator()
#     853     # wrap results
#     854     return self.wrap_results(results, res_index)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/apply.py:867, in FrameApply.apply_series_generator(self)
#     864 with option_context("mode.chained_assignment", None):
#     865     for i, v in enumerate(series_gen):
#     866         # ignore SettingWithCopy here in case the user mutates
# --> 867         results[i] = self.f(v)
#     868         if isinstance(results[i], ABCSeries):
#     869             # If we have a view on v, we need to make a copy because
#     870             #  series_generator will swap out the underlying data
#     871             results[i] = results[i].copy(deep=False)
#
# Input In [207], in convert(row)
#       1 def convert(row):
# ----> 2     cn_code = pc.country_name_to_country_alpha2(row.country, cn_name_format = 'default')
#       4     conti_code = pc.country_alpha2_to_continent_code(cn_code)
#       5     return conti_code
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pycountry_convert/convert_countries.py:71, in country_name_to_country_alpha2(cn_name, cn_name_format)
#      68     return cn_name
#      70 if cn_name not in dict_country_name_to_country_alpha2:
# ---> 71     raise KeyError("Invalid Country Name: '{0}'".format(cn_name))
#      73 return dict_country_name_to_country_alpha2[cn_name]
#
# KeyError: "Invalid Country Name: 'Cote d'Ivoire'"

# %%
print(gmle_2007.head(190))
# Out:
#                             country  2007
# 0                       Afghanistan  59.2
# 1                            Angola  58.8
# 2                           Albania  77.6
# 3                           Andorra  81.8
# 4              United Arab Emirates  70.4
# ..                              ...   ...
# 185                      Uzbekistan  65.7
# 186  St. Vincent and the Grenadines  73.1
# 187                       Venezuela  74.4
# 188                         Vietnam  73.0
# 189                         Vanuatu  64.1
#
# [190 rows x 2 columns]

# %%
gmle_2007.loc[72,'country'] = 'Hong Kong'
gmle_2007.loc[96,'country'] = 'Lao People\'s Democratic Republic'
gmle_2007.loc[186,'country'] = 'Saint Vincent and the Grenadines'
gmle_2007.loc[33,'country'] = 'Côte d\'Ivoire'
gmle_2007.loc[35,'country'] = 'Congo (the Democratic Republic of the)'
gmle_2007.loc[36,'country'] = 'Congo'
gmle_2007.loc[59,'country'] = 'Micronesia (Federated States of)'


print(gmle_2007.head(10))

gmle_2007_drop = gmle_2007.drop([35, 59, 173]) 


# 173 Timor-Leste      # the Country Code was not recognized
# Out:
#                 country  2007
# 0           Afghanistan  59.2
# 1                Angola  58.8
# 2               Albania  77.6
# 3               Andorra  81.8
# 4  United Arab Emirates  70.4
# 5             Argentina  75.7
# 6               Armenia  73.5
# 7   Antigua and Barbuda  75.2
# 8             Australia  81.7
# 9               Austria  80.5

# %%
gmle_2007_drop['continent'] = gmle_2007_drop.apply(convert, axis=1)
print(gmle_2007_drop.head(95))
# Out:
#                              country  2007 continent
# 0                        Afghanistan  59.2        AS
# 1                             Angola  58.8        AF
# 2                            Albania  77.6        EU
# 3                            Andorra  81.8        EU
# 4               United Arab Emirates  70.4        AS
# ..                               ...   ...       ...
# 92                          Kiribati  58.4        OC
# 93               St. Kitts and Nevis  72.0        NA
# 94                       South Korea  80.2        AS
# 95                            Kuwait  78.1        AS
# 96  Lao People's Democratic Republic  63.6        AS
#
# [95 rows x 3 columns]

# %%
continent_dict = {
    'AF': 'Africa',
#    'NA': 'North America',
    'NA': 'Americas',
    'OC': 'Oceania',
    'AN': 'Antarctica',
    'AS': 'Asia',
    'EU': 'Europe',
#    'SA': 'South America',
    'SA': 'Americas',
}

color_dict = {
    'Asia':'red',
    'Europe':'green',
    'Africa':'blue',
    'Americas':'yellow',
    'Oceania':'black'
}




gmle_2007_drop['cont'] = gmle_2007_drop.continent.map(continent_dict)
gmle_2007_drop['color'] = gmle_2007_drop.cont.map(color_dict)

print()
print(gmle_2007_drop.head(40))
# Out:
#       0              1
# 0  Code           Name
# 1    AF         Africa
# 2   NaN  North America
# 3    OC        Oceania
# 4    AN     Antarctica
# 5    AS           Asia
# 6    EU         Europe
# 7    SA  South America
#
#                      country  2007 continent      cont   color
# 0                Afghanistan  59.2        AS      Asia     red
# 1                     Angola  58.8        AF    Africa    blue
# 2                    Albania  77.6        EU    Europe   green
# 3                    Andorra  81.8        EU    Europe   green
# 4       United Arab Emirates  70.4        AS      Asia     red
# 5                  Argentina  75.7        SA  Americas  yellow
# 6                    Armenia  73.5        AS      Asia     red
# 7        Antigua and Barbuda  75.2        NA  Americas  yellow
# 8                  Australia  81.7        OC   Oceania   black
# 9                    Austria  80.5        EU    Europe   green
# 10                Azerbaijan  68.5        AS      Asia     red
# 11                   Burundi  56.8        AF    Africa    blue
# 12                   Belgium  79.9        EU    Europe   green
# 13                     Benin  60.1        AF    Africa    blue
# 14              Burkina Faso  57.1        AF    Africa    blue
# 15                Bangladesh  69.0        AS      Asia     red
# 16                  Bulgaria  71.9        EU    Europe   green
# 17                   Bahrain  74.0        AS      Asia     red
# 18                   Bahamas  73.5        NA  Americas  yellow
# 19    Bosnia and Herzegovina  75.9        EU    Europe   green
# 20                   Belarus  70.5        EU    Europe   green
# 21                    Belize  73.6        NA  Americas  yellow
# 22                   Bolivia  69.8        SA  Americas  yellow
# 23                    Brazil  73.5        SA  Americas  yellow
# 24                  Barbados  75.8        NA  Americas  yellow
# 25                    Brunei  73.8        AS      Asia     red
# 26                    Bhutan  70.3        AS      Asia     red
# 27                  Botswana  54.7        AF    Africa    blue
# 28  Central African Republic  46.8        AF    Africa    blue
# 29                    Canada  81.1        NA  Americas  yellow
# 30               Switzerland  82.4        EU    Europe   green
# 31                     Chile  78.7        SA  Americas  yellow
# 32                     China  74.3        AS      Asia     red
# 33             Côte d'Ivoire  56.3        AF    Africa    blue
# 34                  Cameroon  56.6        AF    Africa    blue
# 36                     Congo  59.4        AF    Africa    blue
# 37                  Colombia  77.6        SA  Americas  yellow
# 38                   Comoros  65.3        AF    Africa    blue
# 39                Cape Verde  73.9        AF    Africa    blue
# 40                Costa Rica  80.3        NA  Americas  yellow

# %%
col = gmle_2007_drop.color.to_list()
print(col)
# Out:
# ['red', 'blue', 'green', 'green', 'red', 'yellow', 'red', 'yellow', 'black', 'green', 'red', 'blue', 'green', 'blue', 'blue', 'red', 'green', 'red', 'yellow', 'green', 'green', 'yellow', 'yellow', 'yellow', 'yellow', 'red', 'red', 'blue', 'blue', 'yellow', 'green', 'yellow', 'red', 'blue', 'blue', 'blue', 'yellow', 'blue', 'blue', 'yellow', 'yellow', 'red', 'green', 'green', 'blue', 'yellow', 'green', 'yellow', 'blue', 'yellow', 'blue', 'blue', 'green', 'green', 'blue', 'green', 'black', 'green', 'blue', 'green', 'red', 'blue', 'blue', 'blue', 'blue', 'blue', 'green', 'yellow', 'yellow', 'yellow', 'red', 'yellow', 'green', 'yellow', 'green', 'red', 'red', 'green', 'red', 'red', 'green', 'red', 'green', 'yellow', 'red', 'red', 'red', 'blue', 'red', 'red', 'black', 'yellow', 'red', 'red', 'red', 'red', 'blue', 'blue', 'yellow', 'red', 'blue', 'green', 'green', 'green', 'blue', 'green', 'green', 'blue', 'red', 'yellow', 'black', 'green', 'blue', 'green', 'red', 'green', 'red', 'blue', 'blue', 'blue', 'blue', 'red', 'blue', 'blue', 'blue', 'yellow', 'green', 'green', 'red', 'black', 'black', 'red', 'red', 'yellow', 'yellow', 'red', 'black', 'black', 'green', 'red', 'green', 'yellow', 'red', 'red', 'green', 'green', 'blue', 'red', 'blue', 'blue', 'red', 'black', 'blue', 'yellow', 'green', 'blue', 'green', 'blue', 'blue', 'yellow', 'green', 'green', 'green', 'blue', 'blue', 'red', 'blue', 'blue', 'red', 'red', 'red', 'black', 'yellow', 'blue', 'red', 'black', 'red', 'blue', 'blue', 'green', 'yellow', 'yellow', 'red', 'yellow', 'yellow', 'red', 'black', 'black', 'red', 'blue', 'blue', 'blue']

# %%
y = gmle_2007_drop['2007'].to_list()
print(y)
# Out:
# [59.2, 58.8, 77.6, 81.8, 70.4, 75.7, 73.5, 75.2, 81.7, 80.5, 68.5, 56.8, 79.9, 60.1, 57.1, 69.0, 71.9, 74.0, 73.5, 75.9, 70.5, 73.6, 69.8, 73.5, 75.8, 73.8, 70.3, 54.7, 46.8, 81.1, 82.4, 78.7, 74.3, 56.3, 56.6, 59.4, 77.6, 65.3, 73.9, 80.3, 78.4, 78.8, 77.3, 80.2, 62.5, 72.7, 79.0, 73.3, 73.9, 73.8, 69.3, 59.1, 81.4, 74.4, 60.8, 80.0, 67.1, 81.2, 62.2, 80.0, 71.5, 61.0, 56.9, 62.9, 54.8, 62.9, 80.0, 72.5, 69.9, 65.3, 82.5, 71.3, 75.9, 60.2, 74.2, 68.9, 66.1, 80.0, 74.8, 69.3, 82.2, 81.0, 81.6, 75.2, 76.2, 83.1, 66.3, 59.4, 68.3, 65.9, 58.4, 72.0, 80.2, 78.1, 63.6, 75.4, 61.1, 75.9, 75.3, 73.3, 46.3, 71.4, 80.6, 72.1, 71.4, 79.1, 69.9, 62.1, 77.2, 75.2, 63.6, 72.9, 57.6, 80.6, 57.7, 74.3, 64.5, 53.4, 67.4, 73.7, 53.4, 74.3, 59.2, 58.3, 58.5, 74.0, 80.5, 80.9, 68.5, 59.3, 80.4, 70.0, 62.9, 78.4, 78.5, 70.4, 67.0, 62.5, 75.6, 70.5, 79.7, 76.0, 69.3, 72.5, 73.4, 67.7, 62.6, 71.4, 66.8, 65.0, 82.1, 57.1, 54.7, 74.7, 81.8, 54.3, 73.5, 60.0, 67.9, 71.7, 75.0, 79.1, 81.5, 45.5, 72.8, 74.4, 55.2, 58.1, 76.5, 67.9, 67.3, 72.1, 72.4, 75.9, 77.0, 66.3, 79.0, 59.6, 57.6, 68.3, 76.2, 78.4, 65.7, 73.1, 74.4, 73.0, 64.1, 69.5, 66.9, 54.3, 54.1, 48.9]

# %%
fn = 'gdppercapita_us_inflation_adjusted.csv'
gdp_cap_inf_adj = pd.read_csv(fn, index_col=0)
gdp_cap_inf_adj_2007 = gdp_cap_inf_adj['2007']
print(gdp_cap_inf_adj_2007.head(30))
# Out:
# country
# Aruba                     30.1k
# Afghanistan                 399
# Angola                     4080
# Albania                    3300
# Andorra                   37.6k
# United Arab Emirates      40.8k
# Argentina                 13.3k
# Armenia                    3340
# American Samoa            12.4k
# Antigua and Barbuda       17.8k
# Australia                 53.3k
# Austria                   44.4k
# Azerbaijan                 4690
# Burundi                     307
# Belgium                   40.2k
# Benin                      1000
# Burkina Faso                554
# Bangladesh                  897
# Bulgaria                   6460
# Bahrain                   21.8k
# Bahamas                   34.2k
# Bosnia and Herzegovina     4130
# Belarus                    5180
# Belize                     4810
# Bermuda                    126k
# Bolivia                    2410
# Brazil                     8260
# Barbados                  18.2k
# Brunei                      34k
# Bhutan                     1910
# Name: 2007, dtype: object

# %%
plt.clf() 
plt.rcParams["figure.figsize"]=15,10

# Store pop as numpy array
np_pop = np.array(pop)

# Double pop numpy array
size = np_pop * 3

plt.scatter(x_drop, y_drop, s = size, c = col)
# plt.xscale('log')

# Add labels
plt.xlabel(xlab)
plt.ylabel(ylab)
plt.title(title)
# plt.xticks(tick_value, tick_lab, rotation=20)
plt.xticks(log_tick_value, log_tick_lab, rotation=20)
plt.show()
plt.clf()

plt.scatter(x_drop, y_drop, s = size, c = col)
plt.xscale('log')

# Add labels
plt.xlabel(xlab)
plt.ylabel(ylab)
plt.title(title)
plt.xticks(tick_value, tick_lab, rotation=20)
# plt.xticks(log_tick_value, log_tick_lab, rotation=20)


plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [173], in <cell line: 3>()
#       1 x_df = pd.DataFrame(x)
#       2 y_df = pd.DataFrame(y)
# ----> 3 x_drop = x_df.drop([33,35, 36, 59, 96, 173, 186])
#       4 y_drop = y_df.drop([33,35, 36, 59, 96, 173, 186])
#       6 plt.clf()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: '[173, 186] not found in axis'

# %%
continent_codes = pd.read_csv('https://datahub.io/core/continent-codes/r/continent-codes.csv', header=None)

continent_codes.loc[2,0] = 'NA'

continent_dict = continent_codes.set_index(0).to_dict()[1]

print(continent_dict)
# Out:
# {'Code': 'Name', 'AF': 'Africa', 'NA': 'North America', 'OC': 'Oceania', 'AN': 'Antarctica', 'AS': 'Asia', 'EU': 'Europe', 'SA': 'South America'}
